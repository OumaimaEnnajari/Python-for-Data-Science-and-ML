# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')   # make a connection between google collab and google drive

# Specify the file path
file_path = '/content/drive/My Drive/iris.csv'

data_frame=pd.read_csv(file_path)
print(data_frame)
# Out:
# Mounted at /content/drive
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(data_frame['sepal_length'], data_frame['sepal_width'])

# %%
sns.pairplot(data_frame)  # afficher toutes les relations entre toutes les colonnes

# %%
sns.pairplot(data_frame, hue='species')  # colorer les points selon leur valeur de species

# %%
data=sns.load_dataset('titanic')
print(data)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(data)

# %%
plt.scatter(data['pclass'], data['age'])

# %%
sns.catplot(x='pclass', y='age', data=data, hue='sex')

# %%
sns.boxplot(x='pclass', y='age', data=data)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.displot(data['fare'])

# %%
sns.jointplot('age', 'fare', data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f4d16802187e> in <cell line: 1>()
# ----> 1 sns.jointplot('age', 'fare', data)
#
# TypeError: jointplot() takes from 0 to 1 positional arguments but 3 were given
